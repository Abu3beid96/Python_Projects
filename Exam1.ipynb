# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the CSV file into a DataFrame

# %%
df= pd.read_csv('iris-data.csv')

# %% [markdown]
# ### Printing the first 5 records

# %%
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#     iris_class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# ### Statistical Summary of the data

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %% [markdown]
# ### Creating a new dataframe for the records of class 'Iris-versicolor'

# %%
df_V=df[df['iris_class']== 'Iris-versicolor']
df_V
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 50            7.000             3.2              4.7             1.4
# 51            6.400             3.2              4.5             1.5
# 52            6.900             3.1              4.9             1.5
# 53            5.500             2.3              4.0             1.3
# 54            6.500             2.8              4.6             1.5
# 55            5.700             2.8              4.5             1.3
# 56            6.300             3.3              4.7             1.6
# 57            4.900             2.4              3.3             1.0
# 58            6.600             2.9              4.6             1.3
# 59            5.200             2.7              3.9             1.4
# 60            5.000             2.0              3.5             1.0
# 61            5.900             3.0              4.2             1.5
# 62            6.000             2.2              4.0             1.0
# ...

# %% [markdown]
# ### Creating an array for versicolor petal length and width

# %%
array1=np.array(df_V[['petal_length_cm']])
array2=np.array(df_V[['petal_width_cm']])

# %%
array1
array2
# Out:
# array([[1.4],
#        [1.5],
#        [1.5],
#        [1.3],
#        [1.5],
#        [1.3],
#        [1.6],
#        [1. ],
#        [1.3],
#        [1.4],
#        [1. ],
#        [1.5],
#        [1. ],
#        [1.4],
#        [1.3],
#        [1.4],
#        [1.5],
#        [1. ],
#        [1.5],
#        [1.1],
#        [1.8],
#        [1.3],
#        [1.5],
#        [1.2],
#        [1.3],
#        [1.4],
#        [1.4],
#        [1.7],
#        [1.5],
#        [1. ],
#        [1.1],
#        [1. ],
#        [1.2],
#        [1.6],
#        [1.5],
#        [1.6],
#        [1.5],
#        [1.3],
#        [1.3],
#        [1.3],
#        [1.2],
#        [1.4],
#        [1.2],
#        [1. ],
#        [1.3],
#        [1.2],
#        [1.3],
#        [1.3],
#        [1.1],
#        [1.3]])

# %% [markdown]
# ### Standard Deviation for both length and width of petal

# %%
df_V.loc[:,"petal_length_cm"].std()
# Out:
# 0.46991097723995806

# %%
df_V.loc[:,"petal_width_cm"].std()
# Out:
# 0.197752680004544

# %% [markdown]
# ### Variance for both length and width of petal

# %%
df_V.loc[:,"petal_length_cm"].var()
# Out:
# 0.22081632653061237

# %%
df_V.loc[:,"petal_width_cm"].var()
# Out:
# 0.039106122448979576

# %% [markdown]
# ### Scatter plot between length and width of the petals

# %%
_=plt.scatter(df_V['petal_length_cm'], df_V['petal_width_cm'])
_=plt.xlabel('petal length')
_=plt.ylabel('petal width')
plt.show()

# %% [markdown]
# ### As observed from the above Scatter plot as the petal length increases the width also increases for most of the records and we also notice that the versicolor petals have a minimal length of about 3.0 cm to a range of 5.0 cm.
