# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_data = pd.read_csv('epldata_final.csv')

# %%
df_data
# Out:
#                         name         club  age position  position_cat  \
# 0             Alexis Sanchez      Arsenal   28       LW             1
# 1                 Mesut Ozil      Arsenal   28       AM             1
# 2                  Petr Cech      Arsenal   35       GK             4
# 3               Theo Walcott      Arsenal   28       RW             1
# 4          Laurent Koscielny      Arsenal   31       CB             3
# 5            Hector Bellerin      Arsenal   22       RB             3
# 6             Olivier Giroud      Arsenal   30       CF             1
# 7              Nacho Monreal      Arsenal   31       LB             3
# 8           Shkodran Mustafi      Arsenal   25       CB             3
# 9                 Alex Iwobi      Arsenal   21       LW             1
# 10              Granit Xhaka      Arsenal   24       DM             2
# 11   Alex Oxlade-Chamberlain      Arsenal   23       RM             2
# ...

# %%
df_sorted=df_data.sort_values('market_value',ascending=False)
df_sorted.head()
# Out:
#                 name               club  age position  position_cat  \
# 92       Eden Hazard            Chelsea   26       LW             1
# 263       Paul Pogba  Manchester+United   24       CM             2
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 240  Kevin De Bruyne    Manchester+City   26       AM             1
# 241    Sergio Aguero    Manchester+City   29       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 92           75.0        4220       10.5   2.30%         224     2.0
# 263          75.0        7435        8.0  19.50%         115     2.0
# 0            65.0        4329       12.0  17.10%         264     3.0
# 240          65.0        2252       10.0  17.50%         199     2.0
# 241          65.0        4046       11.5   9.70%         175     3.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 92      Belgium            0        3        5         1            0
# ...

# %% [markdown]
# ## The table above shows the top 5 most valuable players in EPL

# %%
df_sortedpop=df_data.sort_values('page_views',ascending=False)
df_sortedpop.head()
# Out:
#              name               club  age position  position_cat  \
# 143  Wayne Rooney            Everton   31       SS             1
# 263    Paul Pogba  Manchester+United   24       CM             2
# 376     Dele Alli          Tottenham   21       CM             2
# 93    Diego Costa            Chelsea   28       CF             1
# 1      Mesut Ozil            Arsenal   28       AM             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 143          15.0        7664        7.5  20.90%          76     1.0
# 263          75.0        7435        8.0  19.50%         115     2.0
# 376          45.0        4626        9.5  38.60%         225     1.0
# 93           50.0        4454       10.0   3.00%         196     2.0
# 1            50.0        4395        9.5   5.60%         167     2.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 143     England            0        4        7         0            0
# ...

# %% [markdown]
# ## Considering the number of page views the above table shows the most popular players in EPL also considering that the top 3 are also have the highest FPL popularity

# %%
df_value=df_sorted[['name','market_value']]

# %%
 ax = df_value.plot.bar(x='name', y='market_value', rot=0)

# %% [markdown]
# ## The above plot clearly shows that the market values for EPL is an Exponential Distribution

# %%
df_top6=df_sorted.head()
ax = df_top6.plot.bar(x='name', y='market_value', rot=0)

# %% [markdown]
# ## Here we notice that the market value distribution for the top 6 players is more of a uniform distribution while as the overall all maket value distribution is more of an Exponential Distribution

# %%
 ax = df_sortedpop.plot.bar(x='name', y='page_views', rot=0)

# %%
df_top6pop=df_sortedpop.head()
ax = df_top6pop.plot.bar(x='name', y='page_views', rot=0)

# %% [markdown]
# ## The above Charts show the distribution of the popularity in EPL observing the above chrts we can clearly can conclude that both the distribution of the top 6 and the distribution of the overall data can be consiered Exponentional Distribution

# %%
 ax1 = df_data.plot.scatter(x='age',y='fpl_value', c='DarkBlue')

# %% [markdown]
# ## Here we notice that the highest FPL vaules are concentrated around the middle age players ranging between 25-30

# %%
ax1 = df_data.plot.scatter(x='position_cat',y='fpl_value', c='DarkBlue')

# %% [markdown]
# ## Here we can see that the highest FPL values go to the players who play as attackers

# %%
ax1 = df_data.plot.scatter(x='market_value',y='fpl_value', c='DarkBlue')

# %% [markdown]
# ## Here we can clearly observe that there is an increasing relation ship between the market value and the FPL vaule as the market value increases the FPL value also increases

# %%
ax1 = df_data.plot.scatter(x='age',y='market_value', c='DarkBlue')

# %% [markdown]
# ## Here we can clearly observe that the higher market values go to the middle age players

# %%
df_1=df_data[df_data['club_id'] == 1]
df_1["position_cat"].value_counts()
# Out:
# 3    10
# 1     8
# 2     7
# 4     3
# Name: position_cat, dtype: int64

# %%
df_2=df_data[df_data['club_id'] == 2]
df_2["position_cat"].value_counts()
# Out:
# 1    10
# 3     7
# 2     4
# 4     3
# Name: position_cat, dtype: int64

# %%
df_3=df_data[df_data['club_id'] == 3]
df_3["position_cat"].value_counts()
# Out:
# 3    7
# 1    7
# 2    6
# 4    2
# Name: position_cat, dtype: int64

# %%
df_4=df_data[df_data['club_id'] == 4]
df_4["position_cat"].value_counts()
# Out:
# 2    8
# 3    5
# 1    4
# 4    1
# Name: position_cat, dtype: int64

# %%
df_5=df_data[df_data['club_id'] == 5]
df_5["position_cat"].value_counts()
# Out:
# 3    7
# 1    6
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_6=df_data[df_data['club_id'] == 6]
df_6["position_cat"].value_counts()
# Out:
# 3    8
# 1    7
# 2    4
# 4    2
# Name: position_cat, dtype: int64

# %%
df_7=df_data[df_data['club_id'] == 7]
df_7["position_cat"].value_counts()
# Out:
# 3    10
# 1     9
# 2     6
# 4     3
# Name: position_cat, dtype: int64

# %%
df_8=df_data[df_data['club_id'] == 8]
df_8["position_cat"].value_counts()
# Out:
# 1    11
# 3    10
# 2     5
# 4     2
# Name: position_cat, dtype: int64

# %%
df_9=df_data[df_data['club_id'] == 9]
df_9["position_cat"].value_counts()
# Out:
# 3    8
# 2    7
# 1    7
# 4    2
# Name: position_cat, dtype: int64

# %%
df_10=df_data[df_data['club_id'] == 10]
df_10["position_cat"].value_counts()
# Out:
# 1    11
# 3     8
# 2     6
# 4     2
# Name: position_cat, dtype: int64

# %%
df_11=df_data[df_data['club_id'] == 11]
df_11["position_cat"].value_counts()
# Out:
# 1    8
# 3    5
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_12=df_data[df_data['club_id'] == 12]
df_12["position_cat"].value_counts()
# Out:
# 3    10
# 2     6
# 1     6
# 4     3
# Name: position_cat, dtype: int64

# %%
df_13=df_data[df_data['club_id'] == 13]
df_13["position_cat"].value_counts()
# Out:
# 3    8
# 1    7
# 2    4
# 4    2
# Name: position_cat, dtype: int64

# %%
df_14=df_data[df_data['club_id'] == 14]
df_14["position_cat"].value_counts()
# Out:
# 3    8
# 2    7
# 1    7
# 4    1
# Name: position_cat, dtype: int64

# %%
df_15=df_data[df_data['club_id'] == 15]
df_15["position_cat"].value_counts()
# Out:
# 1    8
# 3    7
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_16=df_data[df_data['club_id'] == 16]
df_16["position_cat"].value_counts()
# Out:
# 1    10
# 3     7
# 2     6
# 4     2
# Name: position_cat, dtype: int64

# %%
df_17=df_data[df_data['club_id'] == 17]
df_17["position_cat"].value_counts()
# Out:
# 3    6
# 2    6
# 1    6
# 4    2
# Name: position_cat, dtype: int64

# %%
df_18=df_data[df_data['club_id'] == 18]
df_18["position_cat"].value_counts()
# Out:
# 3    9
# 1    7
# 2    6
# 4    2
# Name: position_cat, dtype: int64

# %%
df_19=df_data[df_data['club_id'] == 19]
df_19["position_cat"].value_counts()
# Out:
# 1    7
# 3    5
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_20=df_data[df_data['club_id'] == 20]
df_20["position_cat"].value_counts()
# Out:
# 3    8
# 1    8
# 2    4
# 4    2
# Name: position_cat, dtype: int64

# %% [markdown]
# ### The Team with the Most stock on Attackers:
#
#    *Liverpool-11
#    *Hudersfeild-11
#
# ### The Team with the Most stock on  Midfielders :
#
#    *Burnley- 8
#
# ### The Team with the Most stock on Defenders:
#
#    *Arsnel-10
#    *Everton-10
#    *Man. United-10
#
# ### The Team with the Most stock on Goalkeepers:
#
#    *Arsnel-3
#    *Bournemouth-3
#    *Everton-3
#    *Man.United-3

# %%
 ax1 = df_data.plot.scatter(x='fpl_value',y='page_views', c='DarkBlue')

# %% [markdown]
# ## Here we notice that as the popularity increases we notice an increase in FPL value
